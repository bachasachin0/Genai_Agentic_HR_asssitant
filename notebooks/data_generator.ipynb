# %%
import os
from dotenv import load_dotenv
import openai
# Load environment variables from .env file
load_dotenv()

# Access the keys from the .env file
OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")
GROQ_API_KEY = os.getenv("GROQ_API_KEY")
OPEN_AI_EMBEDDING_MODEL = "text-embedding-3-small"
OPEN_AI_EMBEDDING_MODEL_DIMENSION = 256

LANGCHAIN_TRACING_V2 = os.getenv("LANGCHAIN_TRACING_V2", "true")  # Default to True
LANGCHAIN_API_KEY = os.getenv("LANGCHAIN_API_KEY")
LANGCHAIN_ENDPOINT = os.getenv("LANGCHAIN_ENDPOINT", "https://api.smith.langchain.com")
LANGCHAIN_PROJECT = os.getenv("LANGCHAIN_PROJECT")

# %%
import pandas as pd
import random
import json


# Define a list of job titles and departments for variety
job_titles = [
    "Software Engineer", "Senior Software Engineer", "Data Scientist", "Product Manager",
    "Project Manager", "UX Designer", "QA Engineer", "DevOps Engineer", "CTO", "CEO"
]
departments = [
    "IT", "Engineering", "Data Science", "Product", "Project Management", "Design",
    "Quality Assurance", "Operations", "Executive"
]

# Define a list of office locations
office_locations = [
    "Chicago Office", "New York Office", "London Office", "Berlin Office", "Tokyo Office",
    "Sydney Office", "Toronto Office", "San Francisco Office", "Paris Office", "Singapore Office"
]

# Define a function to create a random employee entry
def create_employee(employee_id, first_name, last_name, job_title, department, manager_id=None):
    return {
        "employee_id": employee_id,
        "first_name": first_name,
        "last_name": last_name,
        "gender": random.choice(["Male", "Female"]),
        "date_of_birth": f"{random.randint(1950, 2000)}-{random.randint(1, 12):02}-{random.randint(1, 28):02}",
        "address": {
            "street": f"{random.randint(100, 999)} Main Street",
            "city": "Springfield",
            "state": "IL",
            "postal_code": "62704",
            "country": "USA"
        },
        "contact_details": {
            "email": f"{first_name.lower()}.{last_name.lower()}@example.com",
            "phone_number": f"+1-555-{random.randint(100, 999)}-{random.randint(1000, 9999)}"
        },
        "job_details": {
            "job_title": job_title,
            "department": department,
            "hire_date": f"{random.randint(2000, 2022)}-{random.randint(1, 12):02}-{random.randint(1, 28):02}",
            "employment_type": "Full-Time",
            "salary": random.randint(50000, 250000),
            "currency": "USD"
        },
        "work_location": {
            "nearest_office": random.choice(office_locations),
            "is_remote": random.choice([True, False])
        },
        "reporting_manager": manager_id,
        "skills": random.sample(
            ["JavaScript", "Python", "Node.js", "React", "Django", "Flask", "AWS", "Docker", "Kubernetes", "SQL"], 4
        ),
        "performance_reviews": [
            {
                "review_date": f"{random.randint(2020, 2023)}-{random.randint(1, 12):02}-{random.randint(1, 28):02}",
                "rating": round(random.uniform(3, 5), 1),
                "comments": random.choice([
                    "Exceeded expectations in the last project.",
                    "Consistently meets performance standards.",
                    "Needs improvement in time management.",
                    "Outstanding performance and dedication."
                ])
            },
            {
                "review_date": f"{random.randint(2019, 2022)}-{random.randint(1, 12):02}-{random.randint(1, 28):02}",
                "rating": round(random.uniform(3, 5), 1),
                "comments": random.choice([
                    "Exceeded expectations in the last project.",
                    "Consistently meets performance standards.",
                    "Needs improvement in time management.",
                    "Outstanding performance and dedication."
                ])
            }
        ],
        "benefits": {
            "health_insurance": random.choice(["Gold Plan", "Silver Plan", "Bronze Plan"]),
            "retirement_plan": "401K",
            "paid_time_off": random.randint(15, 30)
        },
        "emergency_contact": {
            "name": f"{random.choice(['Jane', 'Emily', 'Michael', 'Robert'])} {random.choice(['Doe', 'Smith', 'Johnson'])}",
            "relationship": random.choice(["Spouse", "Parent", "Sibling", "Friend"]),
            "phone_number": f"+1-555-{random.randint(100, 999)}-{random.randint(1000, 9999)}"
        },
        "notes": random.choice([
            "Promoted to Senior Software Engineer in 2020.",
            "Completed leadership training in 2021.",
            "Received Employee of the Month award in 2022.",
            "Actively involved in company hackathons and innovation challenges."
        ])
    }

# Generate 10 employee entries
employees = [
    create_employee("E123456", "John", "Doe", "Software Engineer", "IT", "M987654"),
    create_employee("E123457", "Jane", "Doe", "Senior Software Engineer", "IT", "M987654"),
    create_employee("E123458", "Emily", "Smith", "Data Scientist", "Data Science", "M987655"),
    create_employee("E123459", "Michael", "Brown", "Product Manager", "Product", "M987656"),
    create_employee("E123460", "Sarah", "Davis", "Project Manager", "Project Management", "M987657"),
    create_employee("E123461", "Robert", "Johnson", "UX Designer", "Design", "M987658"),
    create_employee("E123462", "David", "Wilson", "QA Engineer", "Quality Assurance", "M987659"),
    create_employee("E123463", "Chris", "Lee", "DevOps Engineer", "Operations", "M987660"),
    create_employee("E123464", "Sophia", "Garcia", "CTO", "Executive", None),
    create_employee("E123465", "Olivia", "Martinez", "CEO", "Executive", None)
]

# %%
# Convert to DataFrame
df_employees = pd.DataFrame(employees)

# Create the 'data' directory if it doesn't exist
data_dir = 'data'
os.makedirs(data_dir, exist_ok=True)

# Save DataFrame to CSV within the 'data' directory
csv_file_employees = os.path.join(data_dir, 'synthetic_data_employees.csv')
df_employees.to_csv(csv_file_employees, index=False)

print(f"Synthetic employee data has been saved to {csv_file_employees}")
# Out:
# Synthetic employee data has been saved to data\synthetic_data_employees.csv

# %%
df_employees.head()
# Out:
#   employee_id first_name last_name  gender date_of_birth  \
# 0     E123456       John       Doe    Male    1961-07-23
# 1     E123457       Jane       Doe    Male    1994-06-08
# 2     E123458      Emily     Smith  Female    1964-08-09
# 3     E123459    Michael     Brown  Female    1969-07-14
# 4     E123460      Sarah     Davis  Female    1974-07-05
#
#                                              address  \
# 0  {'street': '721 Main Street', 'city': 'Springf...
# 1  {'street': '814 Main Street', 'city': 'Springf...
# 2  {'street': '827 Main Street', 'city': 'Springf...
# 3  {'street': '414 Main Street', 'city': 'Springf...
# 4  {'street': '384 Main Street', 'city': 'Springf...
#
#                                      contact_details  \
# 0  {'email': 'john.doe@example.com', 'phone_numbe...
# 1  {'email': 'jane.doe@example.com', 'phone_numbe...
# 2  {'email': 'emily.smith@example.com', 'phone_nu...
# 3  {'email': 'michael.brown@example.com', 'phone_...
# 4  {'email': 'sarah.davis@example.com', 'phone_nu...
#
#                                          job_details  \
# 0  {'job_title': 'Software Engineer', 'department...
# 1  {'job_title': 'Senior Software Engineer', 'dep...
# 2  {'job_title': 'Data Scientist', 'department': ...
# 3  {'job_title': 'Product Manager', 'department':...
# 4  {'job_title': 'Project Manager', 'department':...
#
#                                        work_location reporting_manager  \
# 0  {'nearest_office': 'San Francisco Office', 'is...           M987654
# 1  {'nearest_office': 'London Office', 'is_remote...           M987654
# 2  {'nearest_office': 'London Office', 'is_remote...           M987655
# 3  {'nearest_office': 'Berlin Office', 'is_remote...           M987656
# 4  {'nearest_office': 'Chicago Office', 'is_remot...           M987657
#
#                                   skills  \
# 0     [Django, SQL, Node.js, JavaScript]
# 1          [SQL, Node.js, Flask, Docker]
# 2  [JavaScript, Django, SQL, Kubernetes]
# 3           [React, AWS, Docker, Django]
# 4         [Python, Flask, Docker, React]
#
#                                  performance_reviews  \
# 0  [{'review_date': '2022-02-20', 'rating': 4.4, ...
# 1  [{'review_date': '2021-03-06', 'rating': 4.5, ...
# 2  [{'review_date': '2021-05-17', 'rating': 4.9, ...
# 3  [{'review_date': '2021-01-21', 'rating': 4.2, ...
# 4  [{'review_date': '2021-01-04', 'rating': 3.1, ...
#
#                                             benefits  \
# 0  {'health_insurance': 'Bronze Plan', 'retiremen...
# 1  {'health_insurance': 'Gold Plan', 'retirement_...
# 2  {'health_insurance': 'Silver Plan', 'retiremen...
# 3  {'health_insurance': 'Bronze Plan', 'retiremen...
# 4  {'health_insurance': 'Bronze Plan', 'retiremen...
#
#                                    emergency_contact  \
# 0  {'name': 'Emily Doe', 'relationship': 'Friend'...
# 1  {'name': 'Robert Smith', 'relationship': 'Spou...
# 2  {'name': 'Jane Johnson', 'relationship': 'Spou...
# 3  {'name': 'Robert Doe', 'relationship': 'Parent...
# 4  {'name': 'Emily Johnson', 'relationship': 'Par...
#
#                                                notes
# 0             Completed leadership training in 2021.
# 1  Actively involved in company hackathons and in...
# 2  Actively involved in company hackathons and in...
# 3             Completed leadership training in 2021.
# 4             Completed leadership training in 2021.

# %%
# Function to create a string representation of the employee's key attributes for embedding
def create_employee_string(employee):
    job_details = f"{employee['job_details']['job_title']} in {employee['job_details']['department']}"
    skills = ", ".join(employee['skills'])
    performance_reviews = " ".join([f"Rated {review['rating']} on {review['review_date']}: {review['comments']}" for review in employee['performance_reviews']])
    basic_info = f"{employee['first_name']} {employee['last_name']}, {employee['gender']}, born on {employee['date_of_birth']}"
    work_location = f"Works at {employee['work_location']['nearest_office']}, Remote: {employee['work_location']['is_remote']}"
    notes = employee['notes']

    return f"{basic_info}. Job: {job_details}. Skills: {skills}. Reviews: {performance_reviews}. Location: {work_location}. Notes: {notes}"

# Example usage with one employee
employee_string = create_employee_string(employees[0])
print(f"Here's what an employee string looks like: /n {employee_string}")
# Out:
# Here's what an employee string looks like: /n John Doe, Male, born on 1961-07-23. Job: Software Engineer in IT. Skills: Django, SQL, Node.js, JavaScript. Reviews: Rated 4.4 on 2022-02-20: Exceeded expectations in the last project. Rated 5.0 on 2021-08-13: Needs improvement in time management.. Location: Works at San Francisco Office, Remote: True. Notes: Completed leadership training in 2021.

# %%
# Apply the function to all employees
df_employees['employee_string'] = df_employees.apply(create_employee_string, axis=1)

# %%
from tqdm import tqdm
import google.generativeai as genai


# Generate an embedding using OpenAI's API
def get_embedding(text):
    """Generate an embedding for the given text using OpenAI's API."""

    # Check for valid input
    if not text or not isinstance(text, str):
        return None

    try:
        # Call GOOGLE API to get the embedding
        embeddings = genai.embed_content(model='models/text-embedding-004',
                               content=text,
                               output_dimensionality=768)
        embedding_values=embeddings['embedding']
        return embedding_values
        
    except Exception as e:
        print(f"Error in get_embedding: {e}")
        return None

# Apply the function to generate embeddings for all employees with error handling and progress tracking
try:
    df_employees['embedding'] = [x for x in tqdm(df_employees['employee_string'].apply(get_embedding), total=len(df_employees))]
    print("Embeddings generated for employees")
except Exception as e:
    print(f"Error applying embedding function to DataFrame: {e}")
# Out:
# 100%|██████████| 10/10 [00:00<?, ?it/s]
# Embeddings generated for employees

# %%
df_employees=df_employees.drop('embedding',axis=1)

# %%
df_employees['embedding'][0]
# Out:
# [0.043806758,
#  -0.030823475,
#  -0.038391158,
#  0.05408319,
#  0.055886533,
#  0.09659659,
#  0.044169985,
#  0.0013451948,
#  -0.014090692,
#  0.0072792927,
#  -0.016778884,
#  0.0038886848,
#  0.02768377,
#  -0.007492098,
#  -0.0014154589,
#  -0.03349163,
#  -0.04656331,
#  0.028697317,
#  -0.029724669,
#  -0.059474885,
#  -0.02725797,
#  -0.04624155,
#  0.017957842,
#  -0.026231477,
#  0.0118617555,
#  -0.022214059,
#  -0.05175435,
#  -0.04141484,
#  -0.0014275037,
#  -0.05446551,
#  -0.0049876217,
#  0.02924974,
#  -0.035609514,
#  -0.023383802,
#  -0.032051384,
#  0.045528352,
#  0.0028498305,
#  -0.020597445,
#  0.043200105,
#  -0.042870153,
#  0.007521358,
#  -0.046161007,
#  -0.045230255,
#  0.08243249,
#  -0.034914695,
#  -0.027555225,
#  -0.033487376,
#  -0.041910384,
#  -0.016253473,
#  0.046571642,
#  0.0219142,
#  0.02732512,
#  -0.019135892,
#  0.015180147,
#  -0.012504281,
#  -0.06749682,
#  -0.013798699,
#  -0.048012614,
#  0.0033685192,
#  0.008393977,
#  0.02889702,
#  -0.026073948,
#  -0.04173436,
#  -0.047507692,
#  0.029997906,
#  0.0072051785,
#  0.011745748,
#  0.0030147193,
#  -0.018121136,
#  0.037304584,
#  -0.023982558,
#  -0.025485158,
#  -0.042412408,
#  0.030157568,
#  -0.032049157,
#  -0.016310085,
#  -0.0111004915,
#  -0.06637629,
#  0.037866257,
#  -0.01184495,
#  0.014286814,
#  -0.018092513,
#  0.06131215,
#  -0.011870962,
#  -0.002682089,
#  0.03325873,
#  -0.0290124,
#  -0.057853814,
#  -0.0041055833,
#  -0.024168538,
#  0.08764489,
#  0.03444958,
#  0.021654757,
#  0.014641856,
#  0.013271144,
#  -0.034786962,
#  -0.06476144,
#  -0.013022532,
#  0.10409535,
#  -0.0071007507,
#  0.053385533,
#  0.06446454,
#  -0.009092218,
#  0.04847818,
#  -0.0063927495,
#  0.038559947,
#  -0.086286664,
#  -0.05216169,
#  -0.04600695,
#  -0.037113212,
#  -0.10430537,
#  0.023466373,
#  -0.006292438,
#  0.011874118,
#  0.031012412,
#  0.023441656,
#  -0.0058523393,
#  -0.011673617,
#  -0.05474976,
#  0.0101883635,
#  -0.00900831,
#  0.054130953,
#  0.0050983476,
#  -0.020124502,
#  0.03161082,
#  -0.013821002,
#  -0.008496096,
#  0.03316771,
#  -0.07477835,
#  0.053675797,
#  0.012435658,
#  -0.0031241702,
#  -0.04229888,
#  -0.049063317,
#  0.046893694,
#  0.0119162705]

# %%
df_employees.head()
# Out:
#   employee_id first_name last_name  gender date_of_birth  \
# 0     E123456       John       Doe    Male    1961-07-23
# 1     E123457       Jane       Doe    Male    1994-06-08
# 2     E123458      Emily     Smith  Female    1964-08-09
# 3     E123459    Michael     Brown  Female    1969-07-14
# 4     E123460      Sarah     Davis  Female    1974-07-05
#
#                                              address  \
# 0  {'street': '721 Main Street', 'city': 'Springf...
# 1  {'street': '814 Main Street', 'city': 'Springf...
# 2  {'street': '827 Main Street', 'city': 'Springf...
# 3  {'street': '414 Main Street', 'city': 'Springf...
# 4  {'street': '384 Main Street', 'city': 'Springf...
#
#                                      contact_details  \
# 0  {'email': 'john.doe@example.com', 'phone_numbe...
# 1  {'email': 'jane.doe@example.com', 'phone_numbe...
# 2  {'email': 'emily.smith@example.com', 'phone_nu...
# 3  {'email': 'michael.brown@example.com', 'phone_...
# 4  {'email': 'sarah.davis@example.com', 'phone_nu...
#
#                                          job_details  \
# 0  {'job_title': 'Software Engineer', 'department...
# 1  {'job_title': 'Senior Software Engineer', 'dep...
# 2  {'job_title': 'Data Scientist', 'department': ...
# 3  {'job_title': 'Product Manager', 'department':...
# 4  {'job_title': 'Project Manager', 'department':...
#
#                                        work_location reporting_manager  \
# 0  {'nearest_office': 'San Francisco Office', 'is...           M987654
# 1  {'nearest_office': 'London Office', 'is_remote...           M987654
# 2  {'nearest_office': 'London Office', 'is_remote...           M987655
# 3  {'nearest_office': 'Berlin Office', 'is_remote...           M987656
# 4  {'nearest_office': 'Chicago Office', 'is_remot...           M987657
#
#                                   skills  \
# 0     [Django, SQL, Node.js, JavaScript]
# 1          [SQL, Node.js, Flask, Docker]
# 2  [JavaScript, Django, SQL, Kubernetes]
# 3           [React, AWS, Docker, Django]
# 4         [Python, Flask, Docker, React]
#
#                                  performance_reviews  \
# 0  [{'review_date': '2022-02-20', 'rating': 4.4, ...
# 1  [{'review_date': '2021-03-06', 'rating': 4.5, ...
# 2  [{'review_date': '2021-05-17', 'rating': 4.9, ...
# 3  [{'review_date': '2021-01-21', 'rating': 4.2, ...
# 4  [{'review_date': '2021-01-04', 'rating': 3.1, ...
#
#                                             benefits  \
# 0  {'health_insurance': 'Bronze Plan', 'retiremen...
# 1  {'health_insurance': 'Gold Plan', 'retirement_...
# 2  {'health_insurance': 'Silver Plan', 'retiremen...
# 3  {'health_insurance': 'Bronze Plan', 'retiremen...
# 4  {'health_insurance': 'Bronze Plan', 'retiremen...
#
#                                    emergency_contact  \
# 0  {'name': 'Emily Doe', 'relationship': 'Friend'...
# 1  {'name': 'Robert Smith', 'relationship': 'Spou...
# 2  {'name': 'Jane Johnson', 'relationship': 'Spou...
# 3  {'name': 'Robert Doe', 'relationship': 'Parent...
# 4  {'name': 'Emily Johnson', 'relationship': 'Par...
#
#                                                notes  \
# 0             Completed leadership training in 2021.
# 1  Actively involved in company hackathons and in...
# 2  Actively involved in company hackathons and in...
# 3             Completed leadership training in 2021.
# 4             Completed leadership training in 2021.
#
#                                      employee_string  \
# 0  John Doe, Male, born on 1961-07-23. Job: Softw...
# 1  Jane Doe, Male, born on 1994-06-08. Job: Senio...
# 2  Emily Smith, Female, born on 1964-08-09. Job: ...
# 3  Michael Brown, Female, born on 1969-07-14. Job...
# 4  Sarah Davis, Female, born on 1974-07-05. Job: ...
#
#                                            embedding
# 0  [0.043806758, -0.030823475, -0.038391158, 0.05...
# 1  [0.03555536, -0.033016913, -0.02679502, 0.0296...
# 2  [0.031985004, -0.0021570546, -0.06579504, 0.03...
# 3  [0.031396866, -0.050345022, -0.017025936, 0.01...
# 4  [0.03937773, -0.054149818, -0.047840934, 0.021...

# %%
load_dotenv()
# Out:
# True

# %%
import os


MONGO_URI = os.getenv("MONGO_URI")

# %%
# db_connection.py
import pymongo
from pymongo import MongoClient

def check_mongodb_connection():
    try:
        # Replace with your MongoDB Atlas connection string
        client = MongoClient(MONGO_URI)
        
        # Try performing a simple operation (list databases)
        client.admin.command('ping')
        
        print("MongoDB connection: Successful")
        return True
    except pymongo.errors.ConnectionFailure as e:
        print(f"MongoDB connection: Failed. Error: {e}")
        return False

# Test the connection
if __name__ == "__main__":
    is_connected = check_mongodb_connection()
    if is_connected:
        print("Connection to MongoDB was successful!")
    else:
        print("Failed to connect to MongoDB.")
# Out:
# MongoDB connection: Successful
# Connection to MongoDB was successful!

# %%
from pymongo.mongo_client import MongoClient

DATABASE_NAME = "company_employees"
COLLECTION_NAME = "employees_records"

def get_mongo_client(mongo_uri):
    """Establish connection to the MongoDB and ping the database."""

    # gateway to interacting with a MongoDB database cluster
    client = MongoClient(mongo_uri, appname="hr_agent.python")

    # Ping the database to ensure the connection is successful
    try:
        client.admin.command('ping')
        print("Connection to MongoDB successful")
    except Exception as e:
        print(f"Error connecting to MongoDB: {e}")
        return None

    return client

if not MONGO_URI:
    print("MONGO_URI not set in environment variables")

mongo_client = get_mongo_client(MONGO_URI)

if mongo_client:
    # Pymongo client of database and collection
    db = mongo_client.get_database(DATABASE_NAME)
    collection = db.get_collection(COLLECTION_NAME)
else:
    print("Failed to connect to MongoDB. Exiting...")
    exit(1)
# Out:
# Connection to MongoDB successful

# %%
collection.delete_many({})
# Out:
# DeleteResult({'n': 0, 'electionId': ObjectId('7fffffff000000000000001d'), 'opTime': {'ts': Timestamp(1731513501, 2), 't': 29}, 'ok': 1.0, '$clusterTime': {'clusterTime': Timestamp(1731513501, 2), 'signature': {'hash': b'\xde\xa1?t~\xd3A\xa4> L\x87H\x14\x0f\x81\x89\xe9\x8a\xe7', 'keyId': 7392990737761042438}}, 'operationTime': Timestamp(1731513501, 2)}, acknowledged=True)

# %%
documents = df_employees.to_dict('records')

# Ingest data into MongoDB Database
collection.insert_many(documents)
print("Data ingestion into MongoDB completed")
# Out:
# Data ingestion into MongoDB completed

# %%
from langchain_mongodb.chat_message_histories import MongoDBChatMessageHistory
from langchain.memory import ConversationBufferMemory

def get_session_history(session_id: str) -> MongoDBChatMessageHistory:
  return MongoDBChatMessageHistory(MONGO_URI, session_id, database_name=DATABASE_NAME, collection_name="history")

temp_mem = get_session_history("test")

# %%
# from langchain_openai import ChatOpenAI
from langchain_groq import ChatGroq

from langchain_google_genai import GoogleGenerativeAI
# llm = ChatOpenAI(model="gpt-4o-2024-05-13", temperature=0)
llm = ChatGroq(model="mixtral-8x7b-32768",
    
    temperature=0.1,
    
    
    
    
    )

# %%
# from langchain_openai import OpenAIEmbeddings
from langchain_google_genai import GoogleGenerativeAIEmbeddings

# embedding_model = GoogleGenerativeAIEmbeddings(model="models/embedding-001")

import google.generativeai as genai
from langchain_mongodb import MongoDBAtlasVectorSearch
from langchain.agents import tool, Tool

ATLAS_VECTOR_SEARCH_INDEX = "vector_index"
embedding_model = GoogleGenerativeAIEmbeddings(model='models/text-embedding-004')
# embedding_model = OpenAIEmbeddings(model=OPEN_AI_EMBEDDING_MODEL, dimensions=OPEN_AI_EMBEDDING_MODEL_DIMENSION)

# Vector Store Creation
vector_store = MongoDBAtlasVectorSearch.from_connection_string(
    connection_string=MONGO_URI,
    namespace=DATABASE_NAME + "." + COLLECTION_NAME,
    embedding= embedding_model,
    index_name=ATLAS_VECTOR_SEARCH_INDEX,
    text_key="employee_string"
)

@tool
def lookup_employees(query:str, n=10) -> str:
  "Gathers employee details from the database"
  result = vector_store.similarity_search_with_score(query=query, k=n)
  return str(result)

tools = [lookup_employees]

# %%
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder
from datetime import datetime

def create_agent(llm, tools, system_message: str):
    """Create an agent."""

    prompt = ChatPromptTemplate.from_messages(
        [
            (
                
                "system",
                "You are a helpful AI assistant, collaborating with other assistants."
                " Use the provided tools to progress towards answering the question."
                " If you are unable to fully answer, that's OK, another assistant with different tools "
                " will help where you left off. Execute what you can to make progress."
                " If you or any of the other assistants have the final answer or deliverable,"
                " prefix your response with FINAL ANSWER so the team knows to stop."
                " You have access to the following tools: {tool_names}.\n{system_message}"
                "\nCurrent time: {time}."
            ),
            MessagesPlaceholder(variable_name="messages"),
        ]
    )
    prompt = prompt.partial(system_message=system_message)
    prompt = prompt.partial(time=lambda: str(datetime.now()))
    prompt = prompt.partial(tool_names=", ".join([tool.name for tool in tools]))
    

    return prompt | llm.bind_tools(tools)

# %%
# Chatbot agent and node
chatbot_agent = create_agent(
    llm,
    tools,
    system_message="You are helpful HR Chabot Agent.",
)

# %%
import functools
from langchain_core.messages import AIMessage,ToolMessage

# Helper function to create a node for a given agent
def agent_node(state, agent, name):
    result = agent.invoke(state)
    # We convert the agent output into a format that is suitable to append to the global state
    if isinstance(result, ToolMessage):
        pass
    else:
        result = AIMessage(**result.dict(exclude={"type", "name"}), name=name)
    return {
        "messages": [result],
        # Since we have a strict workflow, we can
        # track the sender so we know who to pass to next.
        "sender": name,
    }

# %%
from langgraph.prebuilt import ToolNode

chatbot_node = functools.partial(agent_node, agent=chatbot_agent, name="HR Chatbot")
tool_node = ToolNode(tools, name="tools")

# %%
import operator
from typing import Annotated, Sequence, TypedDict
from langchain_core.messages import BaseMessage

class AgentState(TypedDict):
    messages: Annotated[Sequence[BaseMessage], operator.add]
    sender: str

# %%
from langgraph.prebuilt import tools_condition
from langgraph.graph import END, StateGraph

workflow = StateGraph(AgentState)

workflow.add_node("chatbot", chatbot_node)
workflow.add_node("tools", tool_node)

workflow.set_entry_point("chatbot")
workflow.add_conditional_edges(
    "chatbot",
    tools_condition,
    {"tools": "tools", END: END}
)

workflow.add_edge("tools", "chatbot")

# %%
graph = workflow.compile()

# %%
from IPython.display import Image, display

try:
    display(Image(graph.get_graph(xray=True).draw_mermaid_png()))
except Exception:
    # This requires some extra dependencies and is optional
    pass

# %%
import pprint
from typing import List, Dict
from langchain_core.messages import BaseMessage, AIMessage, ToolMessage, HumanMessage

events = graph.stream(
  {"messages": [HumanMessage(content="Design an iOS app development team for a new mobile application. Identify the key roles required, including their responsibilities and necessary skills. ")]},
  {"recursion_limit": 17},
)

def process_event(event: Dict) -> List[BaseMessage]:
  new_messages = []
  for value in event.values():
    if isinstance(value, dict) and 'messages' in value:
      for msg in value['messages']:
        if isinstance(msg, BaseMessage):
          new_messages.append(msg)
        elif isinstance(msg, dict) and 'content' in msg:
          new_messages.append(AIMessage(content=msg['content'], additional_kwargs={'sender': msg.get('sender')}))
        elif isinstance(msg, str):
          new_messages.append(ToolMessage(content=msg))
  return new_messages

for event in events:
  print("Event:")
  pprint.pprint(event)
  print("---")

  new_messages = process_event(event)
  if new_messages:
    temp_mem.add_messages(new_messages)

print("\nFinal state of temp_mem:")
if hasattr(temp_mem, 'messages'):
  for msg in temp_mem.messages:
    print(f"Type: {msg.__class__.__name__}")
    print(f"Content: {msg.content}")
    if msg.additional_kwargs:
      print("Additional kwargs:")
      pprint.pprint(msg.additional_kwargs)
    print("---")
else:
   print("temp_mem does not have a 'messages' attribute")
# Out:
# Event:
# {'chatbot': {'messages': [AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_asy8', 'function': {'arguments': '{"query":"iOS app development team roles"}', 'name': 'lookup_employees'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 96, 'prompt_tokens': 1371, 'total_tokens': 1467, 'completion_time': 0.152114271, 'prompt_time': 0.104241258, 'queue_time': 0.0014451129999999979, 'total_time': 0.256355529}, 'model_name': 'mixtral-8x7b-32768', 'system_fingerprint': 'fp_c5f20b5bb1', 'finish_reason': 'tool_calls', 'logprobs': None}, name='HR Chatbot', id='run-7cce8c34-1011-4b9e-b1fe-377322529460-0', tool_calls=[{'name': 'lookup_employees', 'args': {'query': 'iOS app development team roles'}, 'id': 'call_asy8', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1371, 'output_tokens': 96, 'total_tokens': 1467})],
#              'sender': 'HR Chatbot'}}
# ---
# Event:
# {'tools': {'messages': [ToolMessage(content="[(Document(metadata={'_id': '6734cca735ed9f575f1d03d9', 'employee_id': 'E123456', 'first_name': 'John', 'last_name': 'Doe', 'gender': 'Male', 'date_of_birth': '1961-07-23', 'address': {'street': '721 Main Street', 'city': 'Springfield', 'state': 'IL', 'postal_code': '62704', 'country': 'USA'}, 'contact_details': {'email': 'john.doe@example.com', 'phone_number': '+1-555-441-9893'}, 'job_details': {'job_title': 'Software Engineer', 'department': 'IT', 'hire_date': '2004-09-18', 'employment_type': 'Full-Time', 'salary': 184223, 'currency': 'USD'}, 'work_location': {'nearest_office': 'San Francisco Office', 'is_remote': True}, 'reporting_manager': 'M987654', 'skills': ['Django', 'SQL', 'Node.js', 'JavaScript'], 'performance_reviews': [{'review_date': '2022-02-20', 'rating': 4.4, 'comments': 'Exceeded expectations in the last project.'}, {'review_date': '2021-08-13', 'rating': 5.0, 'comments': 'Needs improvement in time management.'}], 'benefits': {'health_insurance': 'Bronze Plan', 'retirement_plan': '401K', 'paid_time_off': 30}, 'emergency_contact': {'name': 'Emily Doe', 'relationship': 'Friend', 'phone_number': '+1-555-188-3818'}, 'notes': 'Completed leadership training in 2021.'}, page_content='John Doe, Male, born on 1961-07-23. Job: Software Engineer in IT. Skills: Django, SQL, Node.js, JavaScript. Reviews: Rated 4.4 on 2022-02-20: Exceeded expectations in the last project. Rated 5.0 on 2021-08-13: Needs improvement in time management.. Location: Works at San Francisco Office, Remote: True. Notes: Completed leadership training in 2021.'), 0.6875063180923462), (Document(metadata={'_id': '6734cca735ed9f575f1d03de', 'employee_id': 'E123461', 'first_name': 'Robert', 'last_name': 'Johnson', 'gender': 'Male', 'date_of_birth': '1998-10-17', 'address': {'street': '950 Main Street', 'city': 'Springfield', 'state': 'IL', 'postal_code': '62704', 'country': 'USA'}, 'contact_details': {'email': 'robert.johnson@example.com', 'phone_number': '+1-555-270-8201'}, 'job_details': {'job_title': 'UX Designer', 'department': 'Design', 'hire_date': '2003-03-23', 'employment_type': 'Full-Time', 'salary': 83011, 'currency': 'USD'}, 'work_location': {'nearest_office': 'San Francisco Office', 'is_remote': True}, 'reporting_manager': 'M987658', 'skills': ['Python', 'Kubernetes', 'React', 'Flask'], 'performance_reviews': [{'review_date': '2022-11-16', 'rating': 4.8, 'comments': 'Exceeded expectations in the last project.'}, {'review_date': '2020-06-12', 'rating': 3.3, 'comments': 'Consistently meets performance standards.'}], 'benefits': {'health_insurance': 'Bronze Plan', 'retirement_plan': '401K', 'paid_time_off': 26}, 'emergency_contact': {'name': 'Robert Johnson', 'relationship': 'Spouse', 'phone_number': '+1-555-996-3630'}, 'notes': 'Promoted to Senior Software Engineer in 2020.'}, page_content='Robert Johnson, Male, born on 1998-10-17. Job: UX Designer in Design. Skills: Python, Kubernetes, React, Flask. Reviews: Rated 4.8 on 2022-11-16: Exceeded expectations in the last project. Rated 3.3 on 2020-06-12: Consistently meets performance standards.. Location: Works at San Francisco Office, Remote: True. Notes: Promoted to Senior Software Engineer in 2020.'), 0.6858645677566528), (Document(metadata={'_id': '6734cca735ed9f575f1d03e0', 'employee_id': 'E123463', 'first_name': 'Chris', 'last_name': 'Lee', 'gender': 'Male', 'date_of_birth': '1985-01-23', 'address': {'street': '905 Main Street', 'city': 'Springfield', 'state': 'IL', 'postal_code': '62704', 'country': 'USA'}, 'contact_details': {'email': 'chris.lee@example.com', 'phone_number': '+1-555-840-8438'}, 'job_details': {'job_title': 'DevOps Engineer', 'department': 'Operations', 'hire_date': '2018-03-24', 'employment_type': 'Full-Time', 'salary': 106815, 'currency': 'USD'}, 'work_location': {'nearest_office': 'London Office', 'is_remote': False}, 'reporting_manager': 'M987660', 'skills': ['Node.js', 'SQL', 'Kubernetes', 'Django'], 'performance_reviews': [ ...
# ---
# Event:
# {'chatbot': {'messages': [AIMessage(content="Based on the tool output, here are the key roles required for an iOS app development team, along with their responsibilities and necessary skills:\n\n1. **Software Engineer (John Doe)**:\n   - Responsible for writing, testing, and maintaining code for iOS applications.\n   - Necessary skills: Django, SQL, Node.js, JavaScript.\n\n2. **UX Designer (Robert Johnson)**:\n   - Responsible for designing the user interface and user experience of the iOS app.\n   - Necessary skills: Python, Kubernetes, React, Flask.\n\n3. **DevOps Engineer (Chris Lee)**:\n   - Responsible for managing the development operations, including deployment, maintenance, and infrastructure management.\n   - Necessary skills: Node.js, SQL, Kubernetes, Django.\n\n4. **Senior Software Engineer (Jane Doe)**:\n   - Responsible for leading the software engineering team, providing technical guidance, and ensuring the quality of the codebase.\n   - Necessary skills: SQL, Node.js, Flask, Docker.\n\n5. **QA Engineer (David Wilson)**:\n   - Responsible for testing the iOS app, identifying bugs, and ensuring the overall quality of the app.\n   - Necessary skills: Django, Flask, Python, SQL.\n\n6. **Data Scientist (Emily Smith)**:\n   - Responsible for analyzing user data, providing insights, and helping to make data-driven decisions.\n   - Necessary skills: JavaScript, Django, SQL, Kubernetes.\n\n7. **Product Manager (Michael Brown)**:\n   - Responsible for managing the product development process, coordinating with the development team, and ensuring the product meets the requirements and expectations of the stakeholders.\n   - Necessary skills: React, AWS, Docker, Django.\n\n8. **CEO (Olivia Martinez)**:\n   - Responsible for leading the organization, making strategic decisions, and ensuring the success of the company.\n   - Necessary skills: Kubernetes, JavaScript, Flask, React.\n\n9. **Project Manager (Sarah Davis)**:\n   - Responsible for managing the project development process, coordinating with the development team, and ensuring the project is completed on time and within budget.\n   - Necessary skills: Python, Flask, Docker, React.\n\n10. **CTO (Sophia Garcia)**:\n    - Responsible for leading the technology team, making technical decisions, and ensuring the alignment of technology with the company's goals.\n    - Necessary skills: Flask, Django, SQL, React.\n\nThese roles and skills should provide a solid foundation for an iOS app development team. However, depending on the specific requirements of the project, additional roles and skills may be necessary.", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 661, 'prompt_tokens': 7829, 'total_tokens': 8490, 'completion_time': 1.05883888, 'prompt_time': 0.895412276, 'queue_time': -0.00011980899999997074, 'total_time': 1.954251156}, 'model_name': 'mixtral-8x7b-32768', 'system_fingerprint': 'fp_c5f20b5bb1', 'finish_reason': 'stop', 'logprobs': None}, name='HR Chatbot', id='run-d854ed58-f77d-4a92-b29f-1d2a87bb9077-0', usage_metadata={'input_tokens': 7829, 'output_tokens': 661, 'total_tokens': 8490})],
#              'sender': 'HR Chatbot'}}
# ---
#
# Final state of temp_mem:
# Type: AIMessage
# Content:
# Additional kwargs:
# {'tool_calls': [{'function': {'arguments': '{"query":"iOS app development team '
#                                            'roles"}',
#                               'name': 'lookup_employees'},
#                  'id': 'call_asy8',
#                  'type': 'function'}]}
# ---
# Type: ToolMessage
# Content: [(Document(metadata={'_id': '6734cca735ed9f575f1d03d9', 'employee_id': 'E123456', 'first_name': 'John', 'last_name': 'Doe', 'gender': 'Male', 'date_of_birth': '1961-07-23', 'address': {'street': '721 Main Street', 'city': 'Springfield', 'state': 'IL', 'postal_code': '62704', 'country': 'USA'}, 'contact_details': {'email': 'john.doe@example.com', 'phone_number': '+1-555-441-9893'}, 'job_details': {'job_title': 'Software Engineer', 'department': 'IT', 'hire_date': '2004-09-18', 'employment_type': 'Full-Time', 'salary': 184223, 'currency': 'USD'}, 'work_location': {'nearest_office': 'San Francisco Office', 'is_remote': True}, 'reporting_manager': 'M987654', 'skills': ['Django', 'SQL', 'Node.js', 'JavaScript'], 'performance_reviews': [{'review_date': '2022-02-20', 'rating': 4.4, 'comments': 'Exceeded expectations in the last project.'}, {'review_date': '2021-08-13', 'rating': 5.0, 'comments': 'Needs improvement in time management.'}], 'benefits': {'health_insurance': 'Bronze Plan', 'retirement_plan': '401K', 'paid_time_off': 30}, 'emergency_contact': {'name': 'Emily Doe', 'relationship': 'Friend', 'phone_number': '+1-555-188-3818'}, 'notes': 'Completed leadership training in 2021.'}, page_content='John Doe, Male, born on 1961-07-23. Job: Software Engineer in IT. Skills: Django, SQL, Node.js, JavaScript. Reviews: Rated 4.4 on 2022-02-20: Exceeded expectations in the last project. Rated 5.0 on 2021-08-13: Needs improvement in time management.. Location: Works at San Francisco Office, Remote: True. Notes: Completed leadership training in 2021.'), 0.6875063180923462), (Document(metadata={'_id': '6734cca735ed9f575f1d03de', 'employee_id': 'E123461', 'first_name': 'Robert', 'last_name': 'Johnson', 'gender': 'Male', 'date_of_birth': '1998-10-17', 'address': {'street': '950 Main Street', 'city': 'Springfield', 'state': 'IL', 'postal_code': '62704', 'country': 'USA'}, 'contact_details': {'email': 'robert.johnson@example.com', 'phone_number': '+1-555-270-8201'}, 'job_details': {'job_title': 'UX Designer', 'department': 'Design', 'hire_date': '2003-03-23', 'employment_type': 'Full-Time', 'salary': 83011, 'currency': 'USD'}, 'work_location': {'nearest_office': 'San Francisco Office', 'is_remote': True}, 'reporting_manager': 'M987658', 'skills': ['Python', 'Kubernetes', 'React', 'Flask'], 'performance_reviews': [{'review_date': '2022-11-16', 'rating': 4.8, 'comments': 'Exceeded expectations in the last project.'}, {'review_date': '2020-06-12', 'rating': 3.3, 'comments': 'Consistently meets performance standards.'}], 'benefits': {'health_insurance': 'Bronze Plan', 'retirement_plan': '401K', 'paid_time_off': 26}, 'emergency_contact': {'name': 'Robert Johnson', 'relationship': 'Spouse', 'phone_number': '+1-555-996-3630'}, 'notes': 'Promoted to Senior Software Engineer in 2020.'}, page_content='Robert Johnson, Male, born on 1998-10-17. Job: UX Designer in Design. Skills: Python, Kubernetes, React, Flask. Reviews: Rated 4.8 on 2022-11-16: Exceeded expectations in the last project. Rated 3.3 on 2020-06-12: Consistently meets performance standards.. Location: Works at San Francisco Office, Remote: True. Notes: Promoted to Senior Software Engineer in 2020.'), 0.6858645677566528), (Document(metadata={'_id': '6734cca735ed9f575f1d03e0', 'employee_id': 'E123463', 'first_name': 'Chris', 'last_name': 'Lee', 'gender': 'Male', 'date_of_birth': '1985-01-23', 'address': {'street': '905 Main Street', 'city': 'Springfield', 'state': 'IL', 'postal_code': '62704', 'country': 'USA'}, 'contact_details': {'email': 'chris.lee@example.com', 'phone_number': '+1-555-840-8438'}, 'job_details': {'job_title': 'DevOps Engineer', 'department': 'Operations', 'hire_date': '2018-03-24', 'employment_type': 'Full-Time', 'salary': 106815, 'currency': 'USD'}, 'work_location': {'nearest_office': 'London Office', 'is_remote': False}, 'reporting_manager': 'M987660', 'skills': ['Node.js', 'SQL', 'Kubernetes', 'Django'], 'performance_reviews': [{'review_date': '2023-03-24', 'ratin ...
# ---
# Type: AIMessage
# Content: Based on the tool output, here are the key roles required for an iOS app development team, along with their responsibilities and necessary skills:
#
# 1. **Software Engineer (John Doe)**:
#    - Responsible for writing, testing, and maintaining code for iOS applications.
#    - Necessary skills: Django, SQL, Node.js, JavaScript.
#
# 2. **UX Designer (Robert Johnson)**:
#    - Responsible for designing the user interface and user experience of the iOS app.
#    - Necessary skills: Python, Kubernetes, React, Flask.
#
# 3. **DevOps Engineer (Chris Lee)**:
#    - Responsible for managing the development operations, including deployment, maintenance, and infrastructure management.
#    - Necessary skills: Node.js, SQL, Kubernetes, Django.
#
# 4. **Senior Software Engineer (Jane Doe)**:
#    - Responsible for leading the software engineering team, providing technical guidance, and ensuring the quality of the codebase.
#    - Necessary skills: SQL, Node.js, Flask, Docker.
#
# 5. **QA Engineer (David Wilson)**:
#    - Responsible for testing the iOS app, identifying bugs, and ensuring the overall quality of the app.
#    - Necessary skills: Django, Flask, Python, SQL.
#
# 6. **Data Scientist (Emily Smith)**:
#    - Responsible for analyzing user data, providing insights, and helping to make data-driven decisions.
#    - Necessary skills: JavaScript, Django, SQL, Kubernetes.
#
# 7. **Product Manager (Michael Brown)**:
#    - Responsible for managing the product development process, coordinating with the development team, and ensuring the product meets the requirements and expectations of the stakeholders.
#    - Necessary skills: React, AWS, Docker, Django.
#
# 8. **CEO (Olivia Martinez)**:
#    - Responsible for leading the organization, making strategic decisions, and ensuring the success of the company.
#    - Necessary skills: Kubernetes, JavaScript, Flask, React.
#
# 9. **Project Manager (Sarah Davis)**:
#    - Responsible for managing the project development process, coordinating with the development team, and ensuring the project is completed on time and within budget.
#    - Necessary skills: Python, Flask, Docker, React.
#
# 10. **CTO (Sophia Garcia)**:
#     - Responsible for leading the technology team, making technical decisions, and ensuring the alignment of technology with the company's goals.
#     - Necessary skills: Flask, Django, SQL, React.
#
# These roles and skills should provide a solid foundation for an iOS app development team. However, depending on the specific requirements of the project, additional roles and skills may be necessary.
# ---

# %%
def clear_history_collection():
    # Connect to MongoDB using your MongoDB URI
    client = MongoClient(MONGO_URI)
    
    # Access the database and collection
    db = client[DATABASE_NAME]
    history_collection = db["history"]
    
    # Delete all documents in the collection
    result = history_collection.delete_many({})
    
    print(f"Deleted {result.deleted_count} documents from the history collection.")

# %%
clear_history_collection()
# Out:
# Deleted 12 documents from the history collection.
